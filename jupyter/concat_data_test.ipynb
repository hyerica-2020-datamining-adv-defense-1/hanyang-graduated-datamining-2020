# %%
from adversarial.attacks import random_attack
from adversarial.utils import *
from adversarial import models
import tensorflow as tf

# %%
test_dloader = dataloader.DataLoader("data", 8, False)

# %%
target_model = models.TargetModel()
target_model.load_custom_weights_for_mobilenet("model/model_20200507_9_1.00_0.0088")

# %%
x, y, adv_y = next(iter(test_dloader))

# %%
adv, _, success = random_attack(target_model, x, adv_y, [0.3])

# %%
x_batch, y_batch = dataloader.concat_data(x, y, adv)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12), dpi=120)

for i in range(8):
    img = x_batch[i].numpy()
    
    plt.subplot(4, 2, i+1)
    plt.imshow(img)

plt.show()
